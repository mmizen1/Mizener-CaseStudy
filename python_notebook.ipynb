# %% [markdown]
# # Python Study Notebook
# All of the materials used for self-teaching Python are taken from [NYU Bootcamp](https://nyu.data-bootcamp.com/mba_outline/). The following notebook represents the topics and code examples taken from the NYU Bootcamp website and executed by Misun Mizener.

# %% [markdown]
# ## Topic 2. Python fundamentals 1
#  Calculations; assignments; strings; lists; tuples; built-in functions; objects; methods; tab completion.
#
#
# ### Calculations

# %%
2**3    #exponents calculation in Python
# Out:
# 8

# %%
x = 2    #variable assignment in Python
x
# Out:
# 2

# %%
w = 7
w = w + 2
w
# Out:
# 9

# %%
w = w + 2
w
# Out:
# 11

# %%
principal = 200    #variable assignment and calculations using variables
i = 0.05
principal + (principal * i)
# Out:
# 210.0

# %%
print(x, y, sep='|')    #separating print variables with characters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9b103bd6ca42> in <module>()
# ----> 1 print(x, y, sep='|')    #separating print variables with characters
#
# NameError: name 'y' is not defined

# %% [markdown]
# ### Creating a word by addition
# Here is an example where I am using the addition function on strings to create the word something

# %%
a = 'some'
b = 'thing'
c = a + b
print('c =', c)
# Out:
# c = something

# %% [markdown]
# ### Creating Lists
# Create lists by putting square brackets around a collection of items separated by commas.

# %%
numberlist = [1, 5, -3] 
stringlist = ['hi', 'hello', 'hey']

# %%
a = 'some'    #creating variablelist
b = 'thing'
c = a + b
variablelist = [a, b, c]

# %%
randomlist = [1, "hello", a]    #shows list can combine variables, numbers, and strings

# %%
biglist = numberlist + stringlist    #produces a list containing all the elements of numberlist plus all the elements of stringlist
print(biglist)
# Out:
# [1, 5, -3, 'hi', 'hello', 'hey']

# %%
biglist2 = [numberlist, stringlist]    #list of lists
print(biglist2)
# Out:
# [[1, 5, -3], ['hi', 'hello', 'hey']]

# %%
print(numberlist)
print(variablelist)
# Out:
# [1, 5, -3]
# ['some', 'thing', 'something']

# %%
mixedlist = [a, b, c, numberlist]
print(mixedlist)
# Out:
# ['some', 'thing', 'something', [1, 5, -3]]

# %%
x = [1, 2, 3]

# %%
x + x    #adding lists
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
2*x
# Out:
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# ### Tuples
# Tuples are ordered collectsion of things in parentheses separated by commas. Similar to lists but syntax is different (parentheses rather than square brackets) and they can't be changed.

# %%
t = (1, 4, -3)    #example of Tuple

# %% [markdown]
# ### Python's built-in functions
# len() = length function. Tells us the length of an object.
# type() = type function. What kind of object it is.

# %%
zoo = ['lions', 'bears']

# %%
type(zoo)
# Out:
# list

# %% [markdown]
# ### Changing types
# * To convert strings to numbers use function float()
# * To convert strings to integers use function int()
# * To convert numbers to strings use function str()
# * To convert strings to lists use function list()

# %%
# example of converting strings to numbers using function float()
s = '12.34'
f = float(s)
type(f)
# Out:
# float

# %%
# example of converting strings to integers using function int()
s = '12'
i = int(s)
type(i)
# Out:
# int

# %%
# example of converting numbers to strings using function str()
s = str(12)
print('s has type', type(s))
t = str(12.34)
print('t has type', type(t))
# Out:
# s has type <class 'str'>
# t has type <class 'str'>

# %%
# example of converting strings to lists using function list()
x = 'abc'
y = list(x)
print(y)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ### Methods
# * objectname.[tab] = tab completion. When you hit tab after a period, a window will pop up with a list of methods in alphabetical order
# * object.method? = get more information about a method

# %%
firstname = 'Chase'

# %%
firstname.lower()    #method to convert all characters to lower case
# Out:
# 'chase'

# %%
firstname.upper()
# Out:
# 'CHASE'

# %%
z = '12,345.6'
z = z.replace(',', '')    #remove comma from string
a = float(z)
type(a)
# Out:
# float

# %%
firstname = 'John'
lastname = 'Lennon'
firstlast = firstname + ' ' + lastname

# %%
firstlast.replace('n', '*')
# Out:
# 'Joh* Le**o*'

# %%
name = 'Jones'

# %% [markdown]
# ## Topic 3. Python fundamentals 2
# True and False; comparisons; conditionals; slicing; loops; function definitions and returns; dictionaries.

# %% [markdown]
# ## Dictionaries
# The term data structure refers to the organization of a collection of data. Strings and lists are examples. Here we look another one: dictionaries. Dictionaries are (unordered) pairs of things defined by curly brackets {} , separated by commas, with the items in each pair separated by colon.

# %%
names = {'Dave':  'Backus', 'Chase': 'Coleman', 'Spencer': 'Lyon', 'Glenn': 'Okun'}
names['Glenn'] ## uses syntax dict[key] to get the key pair of 'Glenn'
# Out:
# 'Okun'

# %%
print(names) ## printing dict comes out in the same order we typed it
# Out:
# {'Dave': 'Backus', 'Chase': 'Coleman', 'Spencer': 'Lyon', 'Glenn': 'Okun'}

# %%
numbers = {1: 'one', 2: 'two', 3:'three'}
print(numbers)
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d = {'Donald': 'Duck', 'Mickey': 'Mouse', 'Donald': 'Trump'} ## Having same values in two different keys 
## overrides the first key pair with the duplicate key
print(d)
# Out:
# {'Donald': 'Trump', 'Mickey': 'Mouse'}

# %%
data = {'Year': [1990, 2000, 2010], 'GDP': [8.95, 12.56, 14.78]}  ## embedded list into a dict
print(data)
# Out:
# {'Year': [1990, 2000, 2010], 'GDP': [8.95, 12.56, 14.78]}

# %% [markdown]
# ## Comparisons
# If we assign a comparison to a variable, we refer to it as a Boolean. Common list of operators used in comparisons:
# * Equals: ==
# * Greater than: >
# * Greater than or equals: >=
# * Does not equal: !=

# %%
1>0
# Out:
# True

# %%
type(1>0)
# Out:
# bool

# %%
not 2>=1
# Out:
# False

# %%
"Sarah" == 'Sarah'
# Out:
# True

# %%
len('Sarah') >= 3
# Out:
# True

# %%
name1 = 'Chaseret'  ## comparison is comparing the alphabetical order of the first char of string
name2 = 'Spencer'
name1 < name2
# Out:
# True

# %% [markdown]
# ## Conditionals (if and else)
# * The if statement ends with a colon.
# * Code that follows is indented exactly four spaces

# %%
if 1 > 0:
    print('1 is greater than 0')
# Out:
# 1 is greater than 0

# %%
x = 7

condition = x > 6

if condition:
    print('if branch')
    print(condition)
else:
    print('else branch')
    print(condition)
# Out:
# if branch
# True

# %%
x = 4

condition = x > 6

if condition:
    print('if branch')
    print(condition)
else:
    print('else branch')
    print(condition)
# Out:
# else branch
# False

# %%
name1 = 'Dave'    ## Program that pritns the name that comes first in alphabetical order
name2 = 'Glenn'

if name1 < name2:
    print(name1 + ' ' + name2)
else:
    print(name2 + ' ' + name1)
# Out:
# Dave Glenn

# %% [markdown]
# ## Slicing strings and lists
# Slicing is specifying the item number in square brackets to access elements of strings and lists. Starts numbering at zero. To get the first item/letter, use objectname[0]. To get last item/letter, use objectname[-1]. To slice (extract) a range of items/letters, objectname[1:3].

# %%
firstname = 'Monty' 
firstname[2]
# Out:
# 'n'

# %%
firstname[-3]
# Out:
# 'n'

# %%
numberlist = [1, 5, -3]
first = numberlist[0]
last = numberlist[-1]
middle = numberlist[1]
print(first)
print(last)
print(middle)
# Out:
# 1
# -3
# 5

# %%
c = 'something'
print('c[1] is', c[1])
print('c[1:2] is', c[1:2])
print('c[1:3] is', c[1:3])
print('c[1:] is', c[1:])
# Out:
# c[1] is o
# c[1:2] is o
# c[1:3] is om
# c[1:] is omething

# %%
lastname = 'Python'
print(lastname[2:])
# Out:
# thon

# %%
numlist = [1, 7, 4, 3]
middle = numlist[1:3]
allbutfirst = numlist[1:]
allbutlast = numlist[0:-1]
print(middle)
print(allbutfirst)
print(allbutlast)
# Out:
# [7, 4]
# [7, 4, 3]
# [1, 7, 4]

# %%
print(c[:3])
print(c[3:])
c[:3] + c[3:]
# Out:
# som
# ething
# 'something'

# %% [markdown]
# ## Loops over lists and strings ( for )

# %%
namelist = ['Chase', 'Dave', 'Sarah', 'Spencer']  # creates the list "namelist"
# below, the word "item" is arbitrary. End the line with a colon. 
for item in namelist:    #goes through the items in the list one at a time
    print(item)   #indent this line exactly 4 spaces
# Out:
# Chase
# Dave
# Sarah
# Spencer

# %%
numlist = [4, -2, 5]   ##using a loop to compute the sum of the elements in a list of numbers
total = 0
for num in numlist:
    total = total + num
    
print(total)
# Out:
# 7

# %%
average = total/len(numlist)   #finds the average of the elements in list
print(average)
# Out:
# 2.3333333333333335

# %%
word = 'anything'    #example to run loops over the chracters in a string
for letter in word:
    print(letter)
# Out:
# a
# n
# y
# t
# h
# i
# n
# g

# %%
vowels = 'aeiouy'    #combining for and if statements
word = 'anything'
for letter in word:
    if letter in vowels:
        print(letter)
# Out:
# a
# y
# i

# %%
for letter in word:    #using not
    if letter not in vowels:
        print(letter)
# Out:
# n
# t
# h
# n
# g

# %%
stuff = ['cat', 3.7, 5, 'dog']

for thing in stuff:
    print(thing)
# Out:
# cat
# 3.7
# 5
# dog

# %%
for thing in stuff:
    print(type(thing))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
for thing in stuff:    # prints only elements that are strings
    if type(thing) is str:
        print(thing)
# Out:
# cat
# dog

# %% [markdown]
# ## Loops over counters range()
# Used to sum or average the values of a variable. range() function gives us all the integers from 0 to n-1

# %%
for number in range(5):    # the variable 'number' can be anything
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for number in range(2, 5):
    print(number)
# Out:
# 2
# 3
# 4

# %%
for number in range(1, 11):
    square = number**2
    print('Number and its square:', number, square)
# Out:
# Number and its square: 1 1
# Number and its square: 2 4
# Number and its square: 3 9
# Number and its square: 4 16
# Number and its square: 5 25
# Number and its square: 6 36
# Number and its square: 7 49
# Number and its square: 8 64
# Number and its square: 9 81
# Number and its square: 10 100

# %%
total = 0    #compute the sum of integers from one to ten
for num in range(1,11):
    total = total + num
    
print(total)
# Out:
# 55

# %%
for num in range(10):
    if num > 5:
        print(num)
# Out:
# 6
# 7
# 8
# 9

# %%
for variable in range(1, 8):
    result = 2**variable
    print(variable, result)
# Out:
# 1 2
# 2 4
# 3 8
# 4 16
# 5 32
# 6 64
# 7 128

# %%
maxnum = 20

total = 0
for num in range(maxnum):
    total = total + num
    if total > 100:
        break
        
print('At num =', num, 'we had total =', total)
# Out:
# At num = 14 we had total = 105

# %%
maturity = 20
coupon = 2
ytm = 0.05

price = 0
for year in range(1, maturity+1):
    price = price + coupon/((1+ytm)**year)
    
price = price + 100/((1+ytm)**maturity)
print('The price of the bond is', price)
# Out:
# The price of the bond is 62.613368972380016

# %% [markdown]
# ## List comprehensions
# We can create lists using implicit loops using list comprehensions

# %%
namelist = ['Chase', 'Dave', 'Sarah', 'Spencer']    ## traditional for loop
for item in namelist:
    print(item)
# Out:
# Chase
# Dave
# Sarah
# Spencer

# %%
[print(item) for item in namelist]    #for loop using list comprehensions
# Out:
# Chase
# Dave
# Sarah
# Spencer
# [None, None, None, None]

# %%
fruit = ['apple', 'banana', 'clementine']
FRUIT = [item.upper() for item in fruit]
print(FRUIT)
# Out:
# ['APPLE', 'BANANA', 'CLEMENTINE']

# %%
fruit6 = [item for item in fruit if len(item)<=6]    #creating a new list containing only items with six letters or less
print(fruit6)
# Out:
# ['apple', 'banana']

# %%
Fruit = [item.capitalize() for item in fruit]     #list with just the first letter capitalized
print(Fruit)
# Out:
# ['Apple', 'Banana', 'Clementine']

# %%
g = [0.02, 0.07, 0.07]
gperc = [(item*100) for item in g]
print(gperc)
# Out:
# [2.0, 7.000000000000001, 7.000000000000001]

# %% [markdown]
# ## Defining functions
# Simplest functions have two components: a name and a list of input arguments. *Standard procedure to include a comment in triple quotes at the top of the function explaining what the function is for.*

# %%
def hello(firstname):    # define the function
    print('Hello', firstname)
    
hello('Chase')    #use the function
# Out:
# Hello Chase

# %%
def squareme(number):
    """
    Takes numerical input and returns its square
    """
    return number**2

square = squareme(7)
print('The square is', square)
# Out:
# The square is 49

# %%
def combine(first, last):
    """
    Takes strings 'first' and 'last' and returns new string 'last, first'
    """
    lastfirst = last + ', ' + first
    return lastfirst             # this is what the function sends back

both = combine('Chase', 'Coleman')    # assign the "return" to both
print(both)
# Out:
# Coleman, Chase

# %%
def power2(n):
    """
    Takes numerical input and returns an arbitrary power of 2
    """
    return 2**n

powertwo = power2(5)
print(powertwo)
# Out:
# 32

# %%
def nextyear(year):
    """
    Takes an integer year and returns the following year
    """
    return year + 1

afteryear = nextyear(2015)
print(afteryear)
# Out:
# 2016

# %%
numlist = [1, 4, 20, 54]
max(numlist)
# Out:
# 54

# %% [markdown]
# ## Programming Style
# * Put overall summary of the program on top in triple quotes. Include purpose of program and name.
# * Lines should be no longer than 79 characters
# * Skip two lines before and after a function definition

# %% [markdown]
# # Topic 4. Python packages and pandas
# pip; condas; pandas; import; Pandas; csv files; reading csv/xls files; dataframes; columns; index; APIs

# %% [markdown]
# ## Python packages
# To import, use "import xyz" (replace xyz with package name) OR "import xyz as x". To call a function from the package, use "xyz.foo". To import the foo function directly, use "from xyz import foo" and foo() can be called without referring the package name. Use "from xyz import *" to import all functions and methods in the package.<br>
# To install a new package, in terminal, insert "conda install [package]"

# %% [markdown]
# ## pandas
# DataFrame =  similar to a sheet of data in Excel<br>
# syntax "'name of data frame' = pd.DataFrame({"Column 1 name": [value1, value2, value3], "Column 2 name": [value1, value2, value3]}_

# %% [markdown]
# ### common data frame methods
# df.shape = returns numbers of rows and columns a.k.a. dimensions of the df <br>
# df.columns.tolist() = returns column names as list<br>
# df.index.tolist()  = returns row names as list<br>
# df.dtypes = returns the data type of each column<br>
# df.transpose() or df.T = transposes (exchanges) columns and rows

# %%
import pandas as pd

# %%
# This dictionary is similar to one that we saw earlier in the class
# It represents GDP/CPI data at 10 year intervals from 1990 to 2010
df = pd.DataFrame({"GDP": [5974.7, 10031.0, 14681.1],
                  "CPI": [127.5, 169.3, 217.488],
                  "Year": [1990, 2000, 2010],
                  "Country": ["US", "US", "US"]})

print(df)
# Out:
#        GDP     CPI  Year Country
# 0   5974.7  127.50  1990      US
# 1  10031.0  169.30  2000      US
# 2  14681.1  217.49  2010      US

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dft  = df.T
print('\n', dft)
# Out:
#                 0        1        2
# GDP        6e+03    1e+04  1.5e+04
# CPI      1.3e+02  1.7e+02  2.2e+02
# Year        1990     2000     2010
# Country       US       US       US

# %%
data = {"countrycode": ['CHN', 'CHN', 'CHN', 'FRA', 'FRA', 'FRA'],
        "pop": [1124.8, 1246.8, 1318.2, 58.2, 60.8, 64.7],
        "rgdpe": [2.611, 4.951, 11.106, 1.294, 1.753, 2.032],
        "year": [1990, 2000, 2010, 1990, 2000, 2010]}
pwt = pd.DataFrame(data)

# %%
print(pwt)
# Out:
#   countrycode     pop  rgdpe  year
# 0         CHN  1124.8   2.61  1990
# 1         CHN  1246.8   4.95  2000
# 2         CHN  1318.2  11.11  2010
# 3         FRA    58.2   1.29  1990
# 4         FRA    60.8   1.75  2000
# 5         FRA    64.7   2.03  2010

# %%
type(data)
# Out:
# dict

# %%
pwt.shape
# Out:
# (6, 4)

# %%
pwt.dtypes
# Out:
# countrycode     object
# pop            float64
# rgdpe          float64
# year             int64
# dtype: object

# %%
pwt.columns.tolist()
# Out:
# ['countrycode', 'pop', 'rgdpe', 'year']

# %%
list(pwt)
# Out:
# ['countrycode', 'pop', 'rgdpe', 'year']

# %% [markdown]
# ## Operating on DataFrames
# Variables = Series. To just refer to only one of the columns (variables), write "name of dataframe"["name of column"]. For example, print(df["GDP"]). To ask its type, "print(type(df['GDP'])).<br>
# A series is essentially a DataFrame with a single variable or column. Series are useful because we can do addition, subtraction, division, and multiplication with them

# %%
print(df['GDP'])
# Out:
# 0     5974.7
# 1    10031.0
# 2    14681.1
# Name: GDP, dtype: float64

# %%
print(type(df['GDP']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Operating on series
print(df["GDP"] + df["GDP"])
print(df["GDP"] - df["GDP"])
print(df["GDP"] / df["CPI"])
print(df["CPI"] * df["CPI"])
# Out:
# 0    11949.4
# 1    20062.0
# 2    29362.2
# Name: GDP, dtype: float64
# 0    0.0
# 1    0.0
# 2    0.0
# Name: GDP, dtype: float64
# 0    46.86
# 1    59.25
# 2    67.50
# dtype: float64
# 0    16256.25
# 1    28662.49
# 2    47301.03
# Name: CPI, dtype: float64

# %%
# constructing new variables from old ones
df['RGDP'] = df['GDP']/df['CPI']
df['GDP_div_1000'] = df['GDP'] / 1000

print(df.RGDP)
print(df.GDP_div_1000)
# Out:
# 0    46.86
# 1    59.25
# 2    67.50
# Name: RGDP, dtype: float64
# 0     5.97
# 1    10.03
# 2    14.68
# Name: GDP_div_1000, dtype: float64

# %%
print('\n', df)
# Out:
#         GDP     CPI  Year Country   RGDP  GDP_div_1000
# 0   5974.7  127.50  1990      US  46.86          5.97
# 1  10031.0  169.30  2000      US  59.25         10.03
# 2  14681.1  217.49  2010      US  67.50         14.68

# %%
# changing column names to lwoer case with list comprehension
df.columns = [var.lower() for var in df.columns]

# %%
print('\n', df)
# Out:
#         gdp     cpi  year country   rgdp  gdp_div_1000
# 0   5974.7  127.50  1990      US  46.86          5.97
# 1  10031.0  169.30  2000      US  59.25         10.03
# 2  14681.1  217.49  2010      US  67.50         14.68

# %%
# Changing column names
df = df.rename(columns={'gdp': 'ngdp'})

# %%
print('\n', df)
# Out:
#        ngdp     cpi  year country   rgdp  gdp_div_1000
# 0   5974.7  127.50  1990      US  46.86          5.97
# 1  10031.0  169.30  2000      US  59.25         10.03
# 2  14681.1  217.49  2010      US  67.50         14.68

# %%
# drop a series or variable
df.drop(['cpi'], axis=1)    ## axis=1 refers to columns; axis=0 refers to rows
# Out:
#       ngdp  year country   rgdp  gdp_div_1000
# 0   5974.7  1990      US  46.86          5.97
# 1  10031.0  2000      US  59.25         10.03
# 2  14681.1  2010      US  67.50         14.68

# %%
# create a variable diff equal to the difference of ngdp and rgdp.
df['diff'] = df['ngdp'] - df['rgdp']
print('\n', df)
# Out:
#        ngdp     cpi  year country   rgdp  gdp_div_1000      diff
# 0   5974.7  127.50  1990      US  46.86          5.97   5927.84
# 1  10031.0  169.30  2000      US  59.25         10.03   9971.75
# 2  14681.1  217.49  2010      US  67.50         14.68  14613.60

# %%
# extract variables ngdp and year
namelist = ['ngdp', 'year']
df_v1 = df[namelist]
print('\n', df_v1)
# Out:
#        ngdp  year
# 0   5974.7  1990
# 1  10031.0  2000
# 2  14681.1  2010

# %%
# drop variable 'diff'
df.drop(['diff'], axis=1)
# Out:
#       ngdp     cpi  year country   rgdp  gdp_div_1000
# 0   5974.7  127.50  1990      US  46.86          5.97
# 1  10031.0  169.30  2000      US  59.25         10.03
# 2  14681.1  217.49  2010      US  67.50         14.68

# %%
print('\n', df)
# Out:
#        ngdp     cpi  year country   rgdp  gdp_div_1000      diff
# 0   5974.7  127.50  1990      US  46.86          5.97   5927.84
# 1  10031.0  169.30  2000      US  59.25         10.03   9971.75
# 2  14681.1  217.49  2010      US  67.50         14.68  14613.60

# %% [markdown]
# ## Saving DataFrame to a local file
# Use the "df.to_" family of methods. Methods "df.to_csv()" and "df.to_excel()" produce csv and Excel files and require file name as input. <br><br>
# We can read from clipboard and write to it. To *paste* a section from clipboard to a DataFrame, use<br>
#     df_clip = dp.read_cliboard()<br><br>
#
# To *copy* a the DataFrame to the clipboard, use<br>
#     df.to_clipboard()<br>

# %% [markdown]
# ## Top and bottom of a DataFrame
# "df.head(n)" extracts the top n observations<br>
# "df.tail(n)" extracts the bottom 5

# %%
# Selecting the first observations and creating a new DataFrame from those observations
h = df.head(2)
print(type(h))
print(h)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       ngdp    cpi  year country   rgdp  gdp_div_1000     diff
# 0   5974.7  127.5  1990      US  46.86          5.97  5927.84
# 1  10031.0  169.3  2000      US  59.25         10.03  9971.75

# %% [markdown]
# ## Setting the index
# Use set_index() method to set the index to whatever you want using "df = df.set_index(['column name'])"

# %%
#reverse the set_index() method using the following
df_reset = df.reset_index()

print('\n',df)
# Out:
#        ngdp     cpi  year country   rgdp  gdp_div_1000      diff
# 0   5974.7  127.50  1990      US  46.86          5.97   5927.84
# 1  10031.0  169.30  2000      US  59.25         10.03   9971.75
# 2  14681.1  217.49  2010      US  67.50         14.68  14613.60

# %% [markdown]
# ## Statistics
# df.mean()<br>
# df.std()<br>
# df.describe()<br><br>
# Pandas is "smart" and only uses these methods on numerical data

# %%
df.mean()
df.std()
df.describe()
# Out:
#            ngdp     cpi    year   rgdp  gdp_div_1000      diff
# count      3.00    3.00     3.0   3.00          3.00      3.00
# mean   10228.93  171.43  2000.0  57.87         10.23  10171.06
# std     4356.57   45.03    10.0  10.39          4.36   4346.31
# min     5974.70  127.50  1990.0  46.86          5.97   5927.84
# 25%     8002.85  148.40  1995.0  53.06          8.00   7949.79
# 50%    10031.00  169.30  2000.0  59.25         10.03   9971.75
# 75%    12356.05  193.39  2005.0  63.38         12.36  12292.67
# max    14681.10  217.49  2010.0  67.50         14.68  14613.60

# %% [markdown]
# ## Plotting
# Most basic is "plot()" method which plots all the variables against the index.

# %%
df_v1.plot()

# %%
# Set year as the index and assign the result to the DataFrame dfi. 
# Use the index method to extract it and verify that year is, in fact, the index
dfi = df.set_index(['year'])
print('\n', dfi)
# Out:
#           ngdp     cpi country   rgdp  gdp_div_1000      diff
# year
# 1990   5974.7  127.50      US  46.86          5.97   5927.84
# 2000  10031.0  169.30      US  59.25         10.03   9971.75
# 2010  14681.1  217.49      US  67.50         14.68  14613.60

# %%
dfi_reset = dfi.reset_index()
print('\n', dfi_reset)
# Out:
#     year     ngdp     cpi country   rgdp  gdp_div_1000      diff
# 0  1990   5974.7  127.50      US  46.86          5.97   5927.84
# 1  2000  10031.0  169.30      US  59.25         10.03   9971.75
# 2  2010  14681.1  217.49      US  67.50         14.68  14613.60

# %%
# Copy the DataFrame df into an empty spreadsheet on your computer using the to_clipboard() method.
df.to_clipboard()

# %%
# Produce a bar chart of df with the statement (Hint: use the docstring for df.plot to see what kind argument does)
dfi.plot.bar()

# %% [markdown]
# ## Data input
# ### Reading internet files

# %%
# Reading internet csv files
import pandas as pd
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp' # break URL into two lines
url2 = '/Materials/master/Data/test.csv'
url = url1 + url2
df = pd.read_csv(url)    #read file and assign to df

# %%
print('\n', df)
# Out:
#        name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp' # break URL into two lines
url2 = '/Materials/master/Data/test.csv'
url = url1 + url2
dfalt = pd.read_csv(url, nrows=2)    #Just imports the first two rows
print('\n', dfalt)
# Out:
#      name  x1  x2   x3
# 0   Dave   1   2  3.5
# 1  Chase   4   3  4.3

# %% [markdown]
# ### Identifying missing or NA values
# Substitute particular string with a different value

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp' # break URL into two lines
url2 = '/Materials/master/Data/test.csv'
url = url1 + url2
dfna = pd.read_csv(url, na_values=[1])    #Any value with 1 will be replaced with NaN
print('\n', dfna)
# Out:
#        name   x1  x2   x3
# 0     Dave  NaN   2  3.5
# 1    Chase  4.0   3  4.3
# 2  Spencer  5.0   6  7.8

# %% [markdown]
# ## Read Excel files

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.xls'
url = url1 + url2
dfx = pd.read_excel(url)
print('\n', dfx)
# Out:
#        name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.csv'
url = url1 + url2
df = pd.read_csv(url)
print('\n', df)

# %%
df = pd.read_csv(url, index_col=0)
print('\n', df)

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.xlsx'    # Trying xlsx instead of xls
url = url1 + url2
dfx = pd.read_excel(url)
print('\n', dfx)

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.csv'
url = url1 + url2
df = pd.read_csv(url, na_values=[1,6])    #Treat 1 and 6 as missing
print('\n', df)

# %% [markdown]
# ## Reading files from your computer

# %%
path = 'C:\\Users\\Misun\\Data_Bootcamp\\test.csv'
#backslashes need to be doulbe backslashes or forward slashes
df = pd.read_csv(path)
print('\n', df)

# %% [markdown]
# ## Data Input: Examples
# ### Penn World Table
# standard database for comparing the incomes of countries. It includes annual data for GDP, GDP per person, employment, hours worked, capital, and many other things. The variables are measured on a comparable basis, with GDP measured in 2005 US dollars.

# %%
url = 'https://www.rug.nl/ggdc/docs/pwt90.xlsx'
pwt = pd.read_excel(url, sheet_name='Data')

# %%
pwt.shape

# %%
list(pwt)

# %%
pwt.head()

# %% [markdown]
# ## Data input 3: API
# ### FRED
# Federal Reserve Economic data.

# %% [markdown]
# ### World Bank
# economic and social statistics for most countries in the world. Variables include GDP, population, education, and infrastructure.

# %% [markdown]
# ## Matplotlib

# %%
# make plots show up in notebook
# %matplotlib inline                     

import pandas as pd                    # data package
import matplotlib.pyplot as plt        # pyplot module

# %% [markdown]
# ### FRED.
#
# The St Louis Fed has put together a large collection of time series data that they refer to as [FRED](https://research.stlouisfed.org/fred2/):  Federal Reserve Economic Data.  They started with the US, but now include data for many countries.
#
# The Pandas docs describe how to access FRED.  Here's an example that reads in quarterly data for US real GDP and real consumption.
#
# * The variable `codes`  -- not to be confused with "code" -- consists of FRED variable codes.  Go to [FRED](https://research.stlouisfed.org/fred2/), use the search box to find the series you want, and look for the variable code at the end of the url in your browser.
# * The variables `start` and `end` contain dates in (year, month, day) format using `datetime.datetime`.
#
# (Taken from [NYU Data Bootcamp](https://github.com/NYUDataBootcamp/Materials/blob/master/Code/notebooks/bootcamp_graphics_s17_MBA.ipynb))

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like
from pandas_datareader import data
import datetime as dt                           # package to handle dates

codes = ['GDPCA', 'PCECCA']                     # real GDP, real consumption (from FRED website)

start = dt.datetime(2003, 1, 1)                 # start date
end = dt.datetime(2013, 1, 1)                   # end date

us = data.DataReader(codes, 'fred', start, end)

us.columns = ['gdp', 'pce']                     #us.set_index (we don't need it now) 

print(us.head(3))
# Out:
#                   gdp       pce
# DATE
# 2003-01-01  13271.081  8867.559
# 2004-01-01  13773.490  9208.180
# 2005-01-01  14234.243  9531.811

# %% [markdown]
# ### World Bank.
#
# The World Bank's [databank](http://data.worldbank.org/) covers economic and social statistics for most countries in the world.
#
# Variables include GDP, population, education, and infrastructure.  <br>
#
#
# (Taken from [NYU Data Bootcamp](https://github.com/NYUDataBootcamp/Materials/blob/master/Code/notebooks/bootcamp_graphics_s17_MBA.ipynb))

# %%
from pandas_datareader import wb

iso_codes = ['BRA', 'CHN', 'FRA', 'IND', 'JPN', 'MEX', 'USA']
var = ['NY.GDP.PCAP.PP.KD']
year = 2013

wbdf = wb.download(indicator=var, country=iso_codes, start=year, end=year)
print(wbdf)
# Out:
#                     NY.GDP.PCAP.PP.KD
# country       year
# Brazil        2013       15430.268276
# China         2013       11951.247959
# France        2013       37366.930722
# India         2013        5073.605489
# Japan         2013       37148.602750
# Mexico        2013       16315.862722
# United States 2013       51008.459971

# %%
# Change the index for iso codes
wbdf.index = iso_codes

# Add country variable 
country = ['Brazil', 'China', 'France', 'India', 'Japan', 'Mexico', 'United States']
wbdf['country'] = country

# Rename the variables
wbdf.columns = ['gdppc', 'country']

# set the display precision in terms of decimal places
pd.set_option('precision', 2)
wbdf['gdppc'] = wbdf['gdppc']/1000

print(wbdf)
# Out:
#      gdppc        country
# BRA  15.43         Brazil
# CHN  11.95          China
# FRA  37.37         France
# IND   5.07          India
# JPN  37.15          Japan
# MEX  16.32         Mexico
# USA  51.01  United States

# %% [markdown]
# ### Fama-French.
#
# * Gene Fama and Ken French post lots of data on equity returns on [Ken French’s website](http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html).
# * The data are zipped text files, which we can easily read into Excel OR
# * use the Pandas tool which is better.

# %%
ff = data.DataReader('F-F_Research_Data_factors', 'famafrench')
ff
# Out:
# {0:          Mkt-RF   SMB   HML    RF
#  Date
#  2010-01   -3.36  0.38  0.31  0.00
#  2010-02    3.40  1.20  3.16  0.00
#  2010-03    6.31  1.42  2.10  0.01
#  2010-04    2.00  4.98  2.81  0.01
#  2010-05   -7.89  0.05 -2.38  0.01
#  2010-06   -5.56 -1.97 -4.50  0.01
#  2010-07    6.93  0.16 -0.27  0.01
#  2010-08   -4.77 -3.00 -1.95  0.01
#  2010-09    9.54  3.92 -3.12  0.01
#  2010-10    3.88  1.15 -2.59  0.01
#  2010-11    0.60  3.70 -0.90  0.01
#  2010-12    6.82  0.70  3.81  0.01
#  2011-01    1.99 -2.47  0.81  0.01
#  2011-02    3.49  1.52  1.09  0.01
#  2011-03    0.45  2.60 -1.55  0.01
#  2011-04    2.90 -0.34 -2.51  0.00
#  2011-05   -1.27 -0.70 -2.06  0.00
#  2011-06   -1.75 -0.18 -0.31  0.00
#  2011-07   -2.36 -1.31 -1.23  0.00
#  2011-08   -5.99 -3.06 -2.44  0.01
#  2011-09   -7.59 -3.48 -1.46  0.00
#  2011-10   11.35  3.41 -0.17  0.00
#  2011-11   -0.28 -0.17 -0.35  0.00
#  2011-12    0.74 -0.71  1.74  0.00
#  2012-01    5.05  2.15 -1.09  0.00
# ...

# %%
# object of above
type(ff)
# Out:
# dict

# %%
ff.keys()
# Out:
# dict_keys([0, 1, 'DESCR'])

# %%
ff['DESCR']
# Out:
# 'F-F Research Data factors\n-------------------------\n\nThis file was created by CMPT_ME_BEME_RETS using the 201804 CRSP database. The 1-month TBill return is from Ibbotson and Associates, Inc. Copyright 2018 Kenneth R. French\n\n  0 : (100 rows x 4 cols)\n  1 : Annual Factors: January-December (8 rows x 4 cols)'

# %%
ff = ff[1]
ff
# Out:
#       Mkt-RF    SMB    HML    RF
# Date
# 2010   17.37  13.80  -5.31  0.12
# 2011    0.44  -6.00  -8.42  0.04
# 2012   16.28  -1.15   9.68  0.06
# 2013   35.20   7.27   1.35  0.02
# 2014   11.70  -8.00  -1.58  0.02
# 2015    0.07  -3.94  -9.56  0.02
# 2016   13.30   6.60  22.91  0.20
# 2017   21.50  -4.84 -13.85  0.80

# %%
ff.columns = ['xsm', 'smb', 'hml', 'rf']

ff['rm'] = ff['xsm'] + ff['rf']
ff = ff[['rm', 'rf']]                    # extract rm (market) and rf (riskfree)

ff.head(5)
# Out:
#          rm    rf
# Date
# 2010  17.49  0.12
# 2011   0.48  0.04
# 2012  16.34  0.06
# 2013  35.22  0.02
# 2014  11.72  0.02

# %% [markdown]
# ---------------------------------------------
#
# ##  Approach 1:  Apply plot methods to dataframes
#
# The simplest way to produce graphics from a dataframe is to apply a plot method to it.
#
# We see that a number of things are preset for us:
#
# * Data.  By default the data consists of the whole dataframe.
# * Chart type.  We have options for lines, bars, or other things, but the default is line
# * `x` and `y` variables.  By default, the `x` variable is the dataframe's index and the `y` variables are the columns of the dataframe -- all of them that can be plotted (e.g. columns with a numeric dtype).
#
# We can change all of these things, but that's always a good starting point.

# %% [markdown]
# ### LINE PLOT - US GDP and Consumption

# %%
# Plot df us
us.plot()

# %%
# Plot US GDP alone
us['gdp'].plot()

# %%
# Another way to plot US GDP alone
us.plot(y='gdp')

# %% [markdown]
# ### BAR CHART

# %%
# bar chart 
us.plot(kind='bar')

# %%
# another way for a bar chart
us.plot.bar()

# %% [markdown]
# ### SCATTER PLOT
# General synatx for a dataframe df is <br>df.plot.scatter(x,y)

# %%
# scatter plot 
# we need to be explicit about the x and y variables: x = 'gdp', y = 'pce'
us.plot.scatter('gdp', 'pce')

# %%
# another way to do a scatter plot
us.plot('gdp', 'pce', kind='scatter')

# %% [markdown]
# Add each of these arguments, one at a time, to `us.plot()`:
#
# * `kind='area'`
# * `subplots=True`
# * `sharey=True`
# * `figsize=(3,6)`
# * `ylim=(0,16000)`
#
# What do they do?

# %%
us.plot(kind='area')

# %%
us.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B7F43D668>,
# ...
#       dtype=object)

# %%
us.plot(sharey=True)

# %%
us.plot(figsize=(3,6))

# %%
us.plot(ylim=(0,16000))

# %% [markdown]
# ### Fama-French data

# %%
# now try a few things with the Fama-French data
ff.plot()

# %%
ff.plot(kind='hist',      ## histogram       
        bins=20,             
        subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B7F7BADD8>,
# ...
#       dtype=object)

# %%
# "smoothed" histogram 
ff.plot(kind='kde', subplots=True, sharex=True)    # smoothed histogram ("kernel density estimate")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B7F867C50>,
# ...
#       dtype=object)

# %%
ff.plot(kind='kde', 
        subplots=True, 
        sharex=True,
        title='Fama-French returns',
        grid=True,
        legend=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B00407630>,
# ...
#       dtype=object)

# %% [markdown]
# ## Approach 2: plot(x,y)
#
# This is a more explicit version of `Matplotlib` graphics in which we specify the `x` and `y` variables directly.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(us.index, us['gdp'])

# %%
# we can do two lines together
plt.plot(us.index, us['gdp'])
plt.plot(us.index, us['pce'])

# %%
# we can also add things to plots 
plt.plot(us.index, us['gdp']) 
plt.plot(us.index, us['pce']) 

plt.title('US GDP', fontsize=14, loc='left')          # add title
plt.ylabel('Billions of 2009 USD')                    # y axis label 
plt.xlabel('Year')                                    # y axis label 
plt.tick_params(labelcolor='red')                     # change tick labels to red
#plt.legend(['GDP', 'Consumption'], loc='best')

# %% [markdown]
# --------------------------------------------------
# ## Approach 3:  Create figure objects and apply methods
#
# This approach is probably the most mysterious, but it's the **best**.
#
# The idea is to use the `matplotlib.pyplot` function `subplots()`, which creates two objects:
# * `fig` : figure object -- blank canvas for creating a figure
# * `ax`  : axis object -- everything in the figure: axes, labels, legend
#
# apply methods on these objects to set the various elements of the graph.
#
# **Create objects.**   We'll see this line over and over:

# %%
fig, ax = plt.subplots(2, 1)             # create fig and ax objects -- nrows, ncols

# %% [markdown]
# Note that we're using the pyplot function subplots() , which creates the objects fig and ax on the left. The subplot() function produces a blank figure, which is displayed in the Jupyter notebook. The names fig and ax can be anything, but these choices are
# standard.<br>
# We say fig is a figure object and ax is an axis object. Once more, the words don't mean what we might think they mean:
# * fig is a blank canvas for creating a figure.
# * ax is everything in it: axes, labels, lines or bars, legend, and so on.
#
# **We create graphs by applying plot-like methods to ax**. Typically do this with dataframe plot methods:<br>
# `fig, axe = plt.subplots()    # create axis object axe`<br>
# `us.plot(ax=axe)    #ax= looks for axis object, axe is it`

# %%
print('fig is ', type(fig))
print('ax  is ', type(ax))
# Out:
# fig is  <class 'matplotlib.figure.Figure'>
# ax  is  <class 'numpy.ndarray'>

# %%
fig, axe = plt.subplots(figsize=(8, 4))

# add things to ax 
us.plot(ax=axe, color = ['red', 'green'])

# %%
# Fama-French example 
fig, ax = plt.subplots()    ## Both statements must be in same cell
ff.plot(ax=ax, 
        kind='line',                 # line plot 
        color=['blue', 'magenta'],   # line color 
        title='Fama-French market and riskfree returns')

# %%
# Fama-French example 
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

ff.plot(ax=ax[0], 
        kind='hist',                 # line plot 
        color=['blue', 'magenta'],   # line color 
        alpha=0.65,
        bins=20,
        title='Fama-French market and riskfree returns')

ff.plot(ax=ax[1], 
        kind='kde',                 # line plot 
        color=['blue', 'magenta'],   # line color 
        title='Fama-French market and riskfree returns',
        alpha=0.65)

fig.tight_layout()

# %%
# Add the argument kind='bar' to convert this into a bar chart.
fig, ax = plt.subplots()    ## Both statements must be in same cell
ff.plot(ax=ax, 
        kind='bar',                 # bar plot 
        color=['blue', 'magenta'],   # bar color 
        title='Fama-French market and riskfree returns')

# %%
# Add the argument kind='bar' to convert this into a bar chart.
# Add the argument alpha=0.65 to the bar chart. 
fig, ax = plt.subplots()    ## Both statements must be in same cell
ff.plot(ax=ax, 
        kind='bar',                 # bar plot 
        color=['blue', 'magenta'],   # bar color 
        title='Fama-French market and riskfree returns',
        alpha=0.65)

# %% [markdown]
# ### Add Bells and Whistles
# Using Axis methods

# %%
fig, ax = plt.subplots()

us.plot(ax=ax)

# Apply axis methods
ax.set_title('US GDP and Consumption', fontsize=14, loc='left')
ax.set_ylabel('Billions of 2013 USD')
ax.legend(['Real GDP', 'Consumption'], loc=0)  # more descriptive variable names 
ax.tick_params(labelcolor='red')               # change tick labels to red
ax.set_ylim(0)
# Out:
# (0, 15949.405799999999)

# %% [markdown]
# Use the set_xlabel() method to add an x-axis label. What would you choose?
# Or would you prefer to leave it empty?

# %%
fig, ax = plt.subplots()

us.plot(ax=ax)

# Apply axis methods
ax.set_title('US GDP and Consumption', fontsize=14, loc='left')
ax.set_ylabel('Billions of 2013 USD')
ax.legend(['Real GDP', 'Consumption'], loc=0)  # more descriptive variable names 
ax.tick_params(labelcolor='red')               # change tick labels to red
ax.set_ylim(0)
ax.set_xlabel('Year')
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# Change the line width to 2 and the line colors to blue and magenta. Hint: Use
# us.plot? to get the documentation.

# %%
fig, ax = plt.subplots()

us.plot(ax=ax,
        color=['blue', 'magenta'],    # Change line colors to blue and magenta
        linewidth=2)    # change line width to 2


# Apply axis methods
ax.set_title('US GDP and Consumption', fontsize=14, loc='left')
ax.set_ylabel('Billions of 2013 USD')
ax.legend(['Real GDP', 'Consumption'], loc=0)  # more descriptive variable names 
ax.tick_params(labelcolor='red')               # change tick labels to red
ax.set_ylim(0)
ax.set_xlabel('Year')
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# Create a line plot for the Fama-French dataframe ff that includes both returns.
# Bonus points: Add a title with the set_title method.

# %%
fig, ax = plt.subplots()    ## Both statements must be in same cell
ff.plot(ax=ax, 
        kind='line',                 # bar plot 
        color=['blue', 'magenta'])   # bar color 

ax.set_title('Fama-French market and riskfree returns')
# Out:
# Text(0.5,1,'Fama-French market and riskfree returns')

# %% [markdown]
# ### Multiple subplots
#
# Same idea, but we create a multidimensional `ax` and apply methods to each component. Here we redo the plots of US GDP and consumption.

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, sharex=True)
print('Object ax has dimension', ax.shape)
# Out:
# Object ax has dimension (2, 2)

# %%
# now add some content 
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True)

us['gdp'].plot(ax=ax[0], color='green')   # first plot
us['pce'].plot(ax=ax[1], color='red')     # second plot

# %% [markdown]
# ## Examples
# ### PISA
# The international test scores often used to compare quality of education across countries.

# %%
url = 'http://dx.doi.org/10.1787/888932937035'
pisa = pd.read_excel(url, 
                     skiprows=18,                    # skip the first 18 rows 
                     skipfooter=7,                   # skip the last 7 
                     usecols=[0,1,9,13],          # select columns 
                     index_col=0,                    # set index = first column
                     header=[0,1]                    # set variable names 
                     )
pisa = pisa.dropna()                                 # drop blank lines 
pisa.columns = ['Math', 'Reading', 'Science']        # simplify variable names

# %%
# bar chart of math scores 
fig, ax = plt.subplots()
pisa['Math'].plot(kind='barh', ax=ax)

# %%
# make the plot taller 
fig, ax = plt.subplots(figsize=(4, 13))  # note figsize 
pisa['Math'].plot(kind='barh', ax=ax)  
ax.set_title('PISA Math Score', loc='left')
# Out:
# Text(0,1,'PISA Math Score')

# %%
# Make US bar red

fig, ax = plt.subplots()
pisa['Math'].plot(ax=ax, kind='barh', figsize=(4,13))
ax.set_title('PISA Math Score', loc='left')

us_index = pisa.index.tolist().index('United States')
ax.get_children()[us_index].set_color('r')

# %% [markdown]
# Create the same graph using 'Reading' score

# %%
fig, ax = plt.subplots()
pisa['Reading'].plot(ax=ax, kind='barh', figsize=(4,13))
ax.set_title('PISA Reading Score', loc='left')

us_index = pisa.index.tolist().index('United States')
ax.get_children()[us_index].set_color('r')

# %% [markdown]
# ### World Bank data
#
# We'll use World Bank data for GDP, GDP per capita, and life expectancy to produce a few graphs and illsutrate some methods we haven't seen yet.
#
# * Bar charts of GDP and GDP per capita
# * Scatter plot (bubble plot) of life expectancy v GDP per capita

# %%
# variable list (GDP, GDP per capita, life expectancy)
var = ['NY.GDP.PCAP.PP.KD', 'NY.GDP.MKTP.PP.KD', 'SP.DYN.LE00.IN']  
# country list (ISO codes)
iso = ['USA', 'FRA', 'JPN', 'CHN', 'IND', 'BRA', 'MEX']
year = 2013

# get data from World Bank 
df = wb.download(indicator=var, country=iso, start=year, end=year)

# massage data
df = df.reset_index(level='year', drop=True)
df.columns = ['gdppc', 'gdp', 'life'] # rename variables
df['pop']  = df['gdp']/df['gdppc']    # population 
df['gdp'] = df['gdp']/10**12          # convert to trillions
df['gdppc'] = df['gdppc']/10**3       # convert to thousands
df['order'] = [5, 3, 1, 4, 2, 6, 0]   # reorder countries
df = df.sort_values(by='order', ascending=False)
df
# Out:
#                gdppc    gdp   life       pop  order
# country
# Mexico         16.32   2.00  76.58  1.23e+08      6
# Brazil         15.43   3.12  74.78  2.02e+08      5
# India           5.07   6.49  67.71  1.28e+09      4
# China          11.95  16.22  75.77  1.36e+09      3
# Japan          37.15   4.73  83.33  1.27e+08      2
# France         37.37   2.47  82.22  6.60e+07      1
# United States  51.01  16.13  78.74  3.16e+08      0

# %%
# We'll use this same basic graph a few times.
# Let's make a function so we don't have to repeat the
# code to create 
def gdp_bar(variable="gdp"):
    fig, ax = plt.subplots()
    df[variable].plot(ax=ax, kind='barh', alpha=0.5)
    ax.set_title('Real GDP', loc='left', fontsize=14)
    ax.set_xlabel('Trillions of US Dollars')
    ax.set_ylabel('')
    return fig, ax
    
gdp_bar()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x18b03d5a2b0>)

# %%
# graph for GDP per capita (per person)
fig, ax = gdp_bar("gdppc")
ax.set_title('GDP Per Capita', loc='left', fontsize=14)
# Out:
# Text(0,1,'GDP Per Capita')

# %% [markdown]
# ### Bubble Plots

# %%
# scatterplot of life expectancy vs gdp per capita
fig, ax = plt.subplots()

ax.scatter(df['gdppc'], df['life'],     # x,y variables
           s=df['pop']/10**6,          # size of bubbles
           alpha=0.5)   
ax.set_title('Life expectancy vs. GDP per capita', loc='left', fontsize=14)
ax.set_xlabel('GDP Per Capita')
ax.set_ylabel('Life Expectancy')
ax.text(58, 66, 'Bubble size represents population', horizontalalignment='right')
# Out:
# Text(58,66,'Bubble size represents population')

# %% [markdown]
# Exercise. Make the bubbles a little bit larger

# %%
# scatterplot of life expectancy vs gdp per capita
fig, ax = plt.subplots()

ax.scatter(df['gdppc'], df['life'],     # x,y variables
           s=df['pop']/8**6,          # size of bubbles
           alpha=0.5)   
ax.set_title('Life expectancy vs. GDP per capita', loc='left', fontsize=14)
ax.set_xlabel('GDP Per Capita')
ax.set_ylabel('Life Expectancy')
ax.text(58, 66, 'Bubble size represents population', horizontalalignment='right')
# Out:
# Text(58,66,'Bubble size represents population')

# %% [markdown]
# **Exercise (challenging).** Add labels to the bubbles so we know which country they correspond to.

# %%
# scatterplot of life expectancy vs gdp per capita
fig, ax = plt.subplots()

ax.scatter(df['gdppc'], df['life'],     # x,y variables
           s=df['pop']/10**6,          # size of bubbles
           alpha=0.5)   

ax.set_title('Life expectancy vs. GDP per capita', loc='left', fontsize=14)
ax.set_xlabel('GDP Per Capita')
ax.set_ylabel('Life Expectancy')
ax.text(58, 66, 'Bubble size represents population', horizontalalignment='right')

for (x, y, country) in zip(df['gdppc'], df['life'], df.index):
    ax.text(x, y, country)

# %% [markdown]
# ## Review
#
# Consider the data from Randal Olson's [blog post](http://www.randalolson.com/2014/06/28/how-to-make-beautiful-data-visualizations-in-python-with-matplotlib/):

# %%
import pandas as pd
data = {'Food': ['French Fries', 'Potato Chips', 'Bacon', 'Pizza', 'Chili Dog'],
        'Calories per 100g':  [607, 542, 533, 296, 260]}
cals = pd.DataFrame(data)

cals
# Out:
#            Food  Calories per 100g
# 0  French Fries                607
# 1  Potato Chips                542
# 2         Bacon                533
# 3         Pizza                296
# 4     Chili Dog                260

# %% [markdown]
# The dataframe `cals` contains the calories in 100 grams of several different foods.
#
#
# **Exercise.** We'll create and modify visualizations of this data:
#
# * Set `'Food'` as the index of `cals`.
# * Create a bar chart with `cals` using figure and axis objects.
# * Add a title.
# * Change the color of the bars.  What color do you prefer?
# * Add the argument `alpha=0.5`.  What does it do?
# * Change your chart to a horizontal bar chart.  Which do you prefer?
# * *Challenging.*  Eliminate the legend.
# * *Challenging.*  Skim the top of Olson's [blog post](http://www.randalolson.com/2014/06/28/how-to-make-beautiful-data-visualizations-in-python-with-matplotlib/). What do you see that you'd like to imitate?

# %%
#Set 'Food' as the index of cals 

cals = cals.set_index(['Food'])

cals
# Out:
#               Calories per 100g
# Food
# French Fries                607
# Potato Chips                542
# Bacon                       533
# Pizza                       296
# Chili Dog                   260

# %%
# Create a bar chart with cals using figure and axis objects.
fig, ax = plt.subplots()

cals.plot(ax=ax, kind='bar')

# %%
# Add a title.
fig, ax = plt.subplots()

cals.plot(ax=ax, kind='bar')

ax.set_title('Food calories')
# Out:
# Text(0.5,1,'Food calories')

# %%
# Change the color of the bars. What color do you prefer?

fig, ax = plt.subplots()

cals.plot(ax=ax, 
          kind='bar', 
          color=['yellow'])

ax.set_title('Food calories')
# Out:
# Text(0.5,1,'Food calories')

# %%
# Add the argument alpha=0.5. What does it do?
fig, ax = plt.subplots()

cals.plot(ax=ax, 
          kind='bar', 
          color=['yellow'],
          alpha=0.5)

ax.set_title('Food calories')
# Out:
# Text(0.5,1,'Food calories')

# %%
# Change your chart to a horizontal bar chart. Which do you prefer?
fig, ax = plt.subplots()

cals.plot(ax=ax, 
          kind='barh', 
          color=['yellow'],
          alpha=0.5)

ax.set_title('Food calories')
# Out:
# Text(0.5,1,'Food calories')

# %%
# Get rid of legend

fig, ax = plt.subplots()

cals.plot(ax=ax, 
          kind='barh', 
          color=['yellow'],
          alpha=0.5,
          legend=False)

ax.set_title('Food calories')
# Out:
# Text(0.5,1,'Food calories')

# %%
cals.plot?

# %% [markdown]
# ## Advanced Pandas: Data cleaning
#
# Taken from NYU Data Bootcamp Topic 9: https://github.com/NYUDataBootcamp/Materials/blob/master/Code/notebooks/bootcamp_pandas_adv1-clean.ipynb

# %%
import sys                             # system module 
import pandas as pd                    # data package
import matplotlib.pyplot as plt        # graphics module  
import datetime as dt                  # date and time module
import numpy as np                     # foundation for pandas 

# %matplotlib inline

# %% [markdown]
# Using pandas to solve issues encountered with existing data such as:
#
# * Numerical data is contaminated by commas (marking thousands) or dollar signs.
# * Row and column labels are contaminated.
# * Missing values are marked erratically.
# * We have too much data, would prefer to choose a subset.
# * Variables run across rows rather than down columns.

# %% [markdown]
# ## Reading tsv files from the web
# Chipotle data

# %%
url = 'https://raw.githubusercontent.com/TheUpshot/chipotle/master/orders.tsv'
chipotle = pd.read_csv(url, sep='\t')               # tab (\t) separated values 
print('Variable dtypes:\n', chipotle.dtypes, sep='')
chipotle.head()
# Out:
# Variable dtypes:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Convert object to float and eliminate dollar sign
# Cleaning item_price column of chipotle

# %%
# create a copy of the df to play with 

chipotle_num = chipotle.copy()
print('Original dtype:', chipotle_num['item_price'].dtype)
# Out:
# Original dtype: object

# %%
# delete dollar signs

chipotle_num['item_price'].str.replace('$', '').head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: object

# %%
# delete dollar signs, convert to float, AND assign back to chipotle_num in one line

chipotle_num['item_price'] = chipotle_num['item_price'].str.replace('$', '').astype(float)
print('New dtype:', chipotle_num['item_price'].dtype)
# Out:
# New dtype: float64

# %%
# assign back to original df for future use 
chipotle = chipotle_num

# %%
print('Variable dtypes:\n', chipotle.dtypes, sep='')
chipotle.head()
# Out:
# Variable dtypes:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ## Example:  World Economic Outlook

# %%
url = 'http://www.imf.org/external/pubs/ft/weo/2016/02/weodata/WEOOct2016all.xls'

weo = pd.read_csv(url, sep = '\t', encoding='latin-1')    ## Added encoding after googling error
weo.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           NGDP_D  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4         Gross domestic product, deflator
#
#                                        Subject Notes              Units  \
# 0  Expressed in billions of national currency uni...  National currency
# 1  Annual percentages of constant price GDP are y...     Percent change
# 2  Expressed in billions of national currency uni...  National currency
# 3  Values are based upon GDP in national currency...       U.S. dollars
# ...

# %%
# Eliminate useless columns
names = list(weo.columns)
names[:8]
# Out:
# ['WEO Country Code',
#  'ISO',
#  'WEO Subject Code',
#  'Country',
#  'Subject Descriptor',
#  'Subject Notes',
#  'Units',
#  'Scale']

# %%
# for var details 
details_list = names[1:5] + [names[6]]
# for years
years_list = names[9:-6]

# %%
weo = pd.read_csv(url, 
                  sep = '\t',
                  index_col='ISO',
                  usecols=details_list + years_list,
                  encoding='latin-1')
weo.head()
# Out:
#     WEO Subject Code      Country                       Subject Descriptor  \
# ISO
# AFG           NGDP_R  Afghanistan  Gross domestic product, constant prices
# AFG        NGDP_RPCH  Afghanistan  Gross domestic product, constant prices
# AFG             NGDP  Afghanistan   Gross domestic product, current prices
# AFG            NGDPD  Afghanistan   Gross domestic product, current prices
# AFG           NGDP_D  Afghanistan         Gross domestic product, deflator
#
#                  Units 1980 1981 1982 1983 1984 1985    ...         2007  \
# ISO                                                     ...
# AFG  National currency  NaN  NaN  NaN  NaN  NaN  NaN    ...      267.177
# AFG     Percent change  NaN  NaN  NaN  NaN  NaN  NaN    ...       13.340
# AFG  National currency  NaN  NaN  NaN  NaN  NaN  NaN    ...      427.495
# AFG       U.S. dollars  NaN  NaN  NaN  NaN  NaN  NaN    ...        8.556
# AFG              Index  NaN  NaN  NaN  NaN  NaN  NaN    ...      160.005
#
# ...

# %%
# Get rid of the bottom row with NaN info

weo = pd.read_csv(url, 
                  sep = '\t',
                  index_col='ISO',
                  usecols=details_list + years_list,
                  skipfooter=1, engine='python',   # skipfooter=1 removes bottom row
                  na_values='n/a',   #missing values
                  thousands =',')    #get rid of , in thousands
weo.tail()
# Out:
#     WEO Subject Code   Country  \
# ISO
# ZWE           GGXWDG  Zimbabwe
# ZWE      GGXWDG_NGDP  Zimbabwe
# ZWE          NGDP_FY  Zimbabwe
# ZWE              BCA  Zimbabwe
# ZWE        BCA_NGDPD  Zimbabwe
#
#                                     Subject Descriptor              Units  \
# ISO
# ZWE                      General government gross debt  National currency
# ZWE                      General government gross debt     Percent of GDP
# ZWE  Gross domestic product corresponding to fiscal...  National currency
# ZWE                            Current account balance       U.S. dollars
# ZWE                            Current account balance     Percent of GDP
#
#        1980    1981    1982    1983    1984    1985   ...      2007     2008  \
# ISO                                                   ...
# ZWE     NaN     NaN     NaN     NaN     NaN     NaN   ...     3.477    4.096
# ZWE     NaN     NaN     NaN     NaN     NaN     NaN   ...    50.061   68.864
# ...

# %% [markdown]
# ### Converting object types to float

# %%
weo.head(1)
# Out:
#     WEO Subject Code      Country                       Subject Descriptor  \
# ISO
# AFG           NGDP_R  Afghanistan  Gross domestic product, constant prices
#
#                  Units 1980 1981 1982 1983 1984 1985   ...        2007  \
# ISO                                                    ...
# AFG  National currency  NaN  NaN  NaN  NaN  NaN  NaN   ...     267.177
#
#         2008     2009     2010     2011     2012     2013     2014     2015  \
# ISO
# AFG  277.498  334.621  362.857  386.368  440.336  457.654  463.520  467.035
#
#         2016
# ISO
# AFG  476.376
#
# [1 rows x 41 columns]

# %%
weo.head(1).dtypes
# Out:
# WEO Subject Code      object
# Country               object
# Subject Descriptor    object
# Units                 object
# 1980                  object
# 1981                  object
# 1982                  object
# 1983                  object
# 1984                  object
# 1985                  object
# 1986                  object
# 1987                  object
# 1988                  object
# 1989                  object
# 1990                  object
# 1991                  object
# 1992                  object
# 1993                  object
# 1994                  object
# 1995                  object
# 1996                  object
# 1997                  object
# 1998                  object
# 1999                  object
# 2000                  object
# 2001                  object
# 2002                  object
# 2003                  object
# 2004                  object
# 2005                  object
# 2006                  object
# 2007                  object
# ...

# %%
# With that out of our way, we can do the conversion for one variable 
weo['1980'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c12e6f09bd9b> in <module>()
#       1 # With that out of our way, we can do the conversion for one variable
# ----> 2 weo['1980'].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...

# %% [markdown]
# The error above indicates that somewhere in `weo['1980']` there is a string value `--`. We want to convert that into `NaN`.

# %%
weo = pd.read_csv(url, 
                  sep = '\t',
                  index_col='ISO',
                  usecols=details_list + years_list,
                  skipfooter=1, engine='python',   # skipfooter=1 removes bottom row
                  na_values=['n/a', '--'],   #missing values
                  thousands =',')    #get rid of , in thousands
weo.tail()
# Out:
#     WEO Subject Code   Country  \
# ISO
# ZWE           GGXWDG  Zimbabwe
# ZWE      GGXWDG_NGDP  Zimbabwe
# ZWE          NGDP_FY  Zimbabwe
# ZWE              BCA  Zimbabwe
# ZWE        BCA_NGDPD  Zimbabwe
#
#                                     Subject Descriptor              Units  \
# ISO
# ZWE                      General government gross debt  National currency
# ZWE                      General government gross debt     Percent of GDP
# ZWE  Gross domestic product corresponding to fiscal...  National currency
# ZWE                            Current account balance       U.S. dollars
# ZWE                            Current account balance     Percent of GDP
#
#       1980   1981   1982   1983   1984   1985   ...      2007    2008    2009  \
# ISO                                             ...
# ZWE    NaN    NaN    NaN    NaN    NaN    NaN   ...     3.477   4.096   5.571
# ZWE    NaN    NaN    NaN    NaN    NaN    NaN   ...    50.061  68.864  68.294
# ...

# %%
# Try converting again
weo['1980'].astype(float)
# Out:
# ISO
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
# AFG        NaN
#         ...
# ZWE        NaN
# ZWE    160.147
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE      7.092
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ZWE        NaN
# ...

# %%
# or for all numeric variables
years = [str(year) for year in range(1980, 2017)]
weo[years] = weo[years].astype(float)

# %%
weo.dtypes
# Out:
# WEO Subject Code       object
# Country                object
# Subject Descriptor     object
# Units                  object
# 1980                  float64
# 1981                  float64
# 1982                  float64
# 1983                  float64
# 1984                  float64
# 1985                  float64
# 1986                  float64
# 1987                  float64
# 1988                  float64
# 1989                  float64
# 1990                  float64
# 1991                  float64
# 1992                  float64
# 1993                  float64
# 1994                  float64
# 1995                  float64
# 1996                  float64
# 1997                  float64
# 1998                  float64
# 1999                  float64
# 2000                  float64
# 2001                  float64
# 2002                  float64
# 2003                  float64
# 2004                  float64
# 2005                  float64
# 2006                  float64
# ...

# %% [markdown]
# ## OECD healthcare statistics
#
# The OECD collects [healthcare data](http://www.oecd.org/els/health-systems/health-data.htm) on lots of (mostly rich) countries, which is helpful in producing comparisons.  Here we use a [spreadsheet](http://www.oecd.org/health/health-systems/OECD-Health-Statistics-2016-Frequently-Requested-Data.xls) that can be found under Frequently Requested Data.

# %%
url1 = 'http://www.oecd.org/health/health-systems/'
url2 = 'OECD-Health-Statistics-2016-Frequently-Requested-Data.xls'
oecd = pd.read_excel(url1 + url2)
oecd.head()
# Out:
#     OECD Health Statistics 2016 - Frequently Requested Data
# NaN                                       OCTOBER 2016
# NaN                                                NaN
# NaN  Note: Latvia has joined the OECD in July 2016,...
# NaN                                                NaN
# NaN               OECD Health Statistics 2016: website

# %%
oecd = pd.read_excel(url1 + url2, sheet_name='Physicians')
oecd.head()
# Out:
#                                HEALTH CARE RESOURCES Unnamed: 1 Unnamed: 2  \
# 0  Physicians, Density per 1 000 population (head...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN       1960       1961
# 3                                        Australia 1         ..       1.13
# 4                                          Austria 1       1.59       1.58
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2       1962       1963       1964       1965       1966       1967
# 3         ..         ..       1.23       1.22       1.23       1.26
# 4       1.57       1.56       1.56       1.56       1.57       1.58
#
#   Unnamed: 9           ...           Unnamed: 49 Unnamed: 50 Unnamed: 51  \
# ...

# %%
# Skip the three empty lines
oecd = pd.read_excel(url1 + url2, sheet_name='Physicians', skiprows=3)
oecd.head()
# Out:
#     Unnamed: 0  1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# 0  Australia 1    ..  1.13    ..    ..  1.23  1.22  1.23  1.26  1.24
# 1    Austria 1  1.59  1.58  1.57  1.56  1.56  1.56  1.57  1.58   1.6
# 2    Belgium 1  1.28  1.35   1.4  1.42  1.44  1.46  1.49  1.52  1.55
# 3     Canada 2    ..  1.14  1.22  1.24  1.26  1.27   1.3  1.32  1.33
# 4      Chile 3    ..    ..    ..    ..    ..    ..    ..    ..    ..
#
#            ...            2008  2009  2010  2011  2012  2013  2014  2015  \
# 0          ...            3.02  3.12    ..  3.32  3.31   3.4  3.47    ..
# 1          ...             4.6  4.69   4.8  4.84   4.9  4.99  5.05  5.13
# 2          ...            2.92  2.92  2.92  2.91  2.93  2.95  2.97    ..
# 3          ...            2.26  2.34  2.38  2.46  2.51  2.57  2.61    ..
# 4          ...              ..    ..  1.43  1.58  1.74  1.88  2.02   NaN
#
#   Unnamed: 57 2014 (or nearest year)
# 0         NaN                   3.47
# ...

# %%
# Make countries as indices
oecd = pd.read_excel(url1 + url2, 
                     sheetname='Physicians', 
                     skiprows=3, 
                     index_col=0)
oecd.head()
# Out:
# C:\Users\Misun\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#              1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# Australia 1    ..  1.13    ..    ..  1.23  1.22  1.23  1.26  1.24  1.26
# Austria 1    1.59  1.58  1.57  1.56  1.56  1.56  1.57  1.58   1.6  1.63
# Belgium 1    1.28  1.35   1.4  1.42  1.44  1.46  1.49  1.52  1.55  1.55
# Canada 2       ..  1.14  1.22  1.24  1.26  1.27   1.3  1.32  1.33  1.38
# Chile 3        ..    ..    ..    ..    ..    ..    ..    ..    ..    ..
#
#                      ...            2008  2009  2010  2011  2012  2013  2014  \
# Australia 1          ...            3.02  3.12    ..  3.32  3.31   3.4  3.47
# Austria 1            ...             4.6  4.69   4.8  4.84   4.9  4.99  5.05
# Belgium 1            ...            2.92  2.92  2.92  2.91  2.93  2.95  2.97
# ...
